# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from stemgraphic import stem_graphic

# %%
df = pd.read_csv('bear_info_male.csv')
df.describe()
# Out:
#               Age      Month   Sex  Headlength  Headwidth       Neck  \
# count   35.000000  35.000000  35.0   35.000000  35.000000  35.000000
# mean    39.342857   8.485714   1.0   13.228571   6.471429  21.714286
# std     34.871143   1.990735   0.0    2.301990   1.688816   5.719273
# min      8.000000   4.000000   1.0    9.000000   4.000000  13.000000
# 25%     16.500000   7.500000   1.0   11.500000   5.000000  17.000000
# 50%     32.000000   9.000000   1.0   13.500000   6.000000  21.500000
# 75%     53.000000  10.000000   1.0   15.500000   8.000000  27.000000
# max    177.000000  11.000000   1.0   17.000000  10.000000  31.500000
#
#           Length      Chest      Weight
# count  35.000000  35.000000   35.000000
# mean   59.422857  36.808571  199.742857
# std    11.640929   9.898169  134.054059
# min    37.000000  19.000000   34.000000
# 25%    49.500000  29.250000   88.000000
# 50%    61.000000  35.000000  154.000000
# 75%    69.500000  44.250000  301.000000
# max    76.500000  55.000000  514.000000

# %%
stem_graphic(df['Age'])
# Out:
# (<Figure size 540x378 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x11682eed0>)

# %%
data = df['Month']
bins = np.arange(4,13)-0.5

hist, edges = np.histogram(data, bins=bins)

y = np.arange(1,hist.max()+1)
x = np.arange(4,12)
X,Y = np.meshgrid(x,y)

plt.scatter(X,Y, c=Y<=hist, cmap="Greys")
plt.xlabel('Month of Measurement',fontsize=15)
plt.ylabel('No. of Bears',fontsize=15)
plt.title('Bear Month of Measurement',fontsize=15)

plt.show()

# %%
data = df['Headlength']
plt.hist(data, bins=np.arange(min(data),max(data)+2)-0.5, ec="k")

plt.xticks(range(9,18))
plt.xlabel('Headlength (in.)',fontsize=15)
plt.ylabel('No. of Bears',fontsize=15)
plt.title('Bear Headlength',fontsize=15)
plt.show()

# %%
# TODO: Head Width (bar)

# %%
plt.boxplot(df['Neck'], vert=False)

plt.yticks([])
plt.xlabel('Neck (in.)',fontsize=15)
plt.title('Bear Neck Length',fontsize=15)
plt.show()

# %%
plt.boxplot(df['Length'], vert=False)

plt.yticks([])
plt.xlabel('Length (in.)',fontsize=15)
plt.title('Bear Length',fontsize=15)
plt.show()

# %%
plt.boxplot(df['Chest'], vert=False)

plt.yticks([])
plt.xlabel('Chest (in.)',fontsize=15)
plt.title('Bear Chest Length',fontsize=15)
plt.show()

# %%
plt.boxplot(df['Weight'], vert=False)

plt.yticks([])
plt.xlabel('Weight (lbs.)',fontsize=15)
plt.title('Bear Weight',fontsize=15)
plt.show()
